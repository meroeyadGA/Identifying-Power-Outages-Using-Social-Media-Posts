# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %%
# Import weather data from year 2014 - 2019 for 8 states
data_list = []
for i in range(1, 9):
    data = pd.read_csv(f"../Data/WeatherData_2014_2019_State_{i}.csv", encoding = 'unicode_escape', index_col=None, header=0)
    data_list.append(data)
df = pd.concat(data_list, axis=0, ignore_index=True)

# %%
df.head()
# Out:
#    EVENT_ID                        CZ_NAME_STR BEGIN_LOCATION BEGIN_DATE  \
# 0    497009  SOUTHERN SACRAMENTO VALLEY (ZONE)                    1/1/14
# 1    498466          SE KERN CTY DESERT (ZONE)                    1/1/14
# 2    498465            INDIAN WELLS VLY (ZONE)                    1/1/14
# 3    498464             TULARE CTY MTNS (ZONE)                    1/1/14
# 4    498463               S SIERRA MTNS (ZONE)                    1/1/14
#
#    BEGIN_TIME  Time                     time_location EVENT_TYPE MAGNITUDE  \
# 0           0  0:00  2014-01-01  0:00:00 | California    Drought
# 1           0  0:00  2014-01-01  0:00:00 | California    Drought
# 2           0  0:00  2014-01-01  0:00:00 | California    Drought
# 3           0  0:00  2014-01-01  0:00:00 | California    Drought
# 4           0  0:00  2014-01-01  0:00:00 | California    Drought
#
#   TOR_F_SCALE  ...  END_RANGE  END_AZIMUTH  END_LOCATION  BEGIN_LAT BEGIN_LON  \
# 0              ...
# 1              ...
# ...

# %%
df.tail()
# Out:
#        EVENT_ID       CZ_NAME_STR        BEGIN_LOCATION BEGIN_DATE  \
# 53713    845037       SPOKANE CO.               SPOKANE    7/23/19
# 53714    845008       SPOKANE CO.               SPOKANE    7/23/19
# 53715    836472       SPOKANE CO.  (SFF)FELTS FLD SPOKA    7/23/19
# 53716    834019         FERRY CO.                METEOR    7/23/19
# 53717    834018  PEND OREILLE CO.               NEWPORT    7/23/19
#
#        BEGIN_TIME   Time                      time_location  \
# 53713        2000  20:00  2019-07-23  20:00:00 | Washington
# 53714        2015  20:15  2019-07-23  20:00:00 | Washington
# 53715        2021  20:21  2019-07-23  20:00:00 | Washington
# 53716        2030  20:30  2019-07-23  20:00:00 | Washington
# 53717        2050  20:50  2019-07-23  20:00:00 | Washington
#
#               EVENT_TYPE MAGNITUDE TOR_F_SCALE  ...  END_RANGE  END_AZIMUTH  \
# 53713  Thunderstorm Wind        52              ...          1          ESE
# ...

# %%
df.dtypes
# Out:
# EVENT_ID                int64
# CZ_NAME_STR            object
# BEGIN_LOCATION         object
# BEGIN_DATE             object
# BEGIN_TIME              int64
# Time                   object
# time_location          object
# EVENT_TYPE             object
# MAGNITUDE              object
# TOR_F_SCALE            object
# DEATHS_DIRECT           int64
# INJURIES_DIRECT         int64
# DAMAGE_PROPERTY_NUM     int64
# DAMAGE_CROPS_NUM        int64
# STATE                  object
# CZ_TIMEZONE            object
# MAGNITUDE_TYPE         object
# EPISODE_ID              int64
# CZ_TYPE                object
# CZ_FIPS                 int64
# WFO                    object
# INJURIES_INDIRECT       int64
# DEATHS_INDIRECT         int64
# SOURCE                 object
# FLOOD_CAUSE            object
# TOR_LENGTH             object
# TOR_WIDTH              object
# BEGIN_RANGE            object
# BEGIN_AZIMUTH          object
# END_RANGE              object
# END_AZIMUTH            object
# ...

# %%
# Fill NA with "Unknown"
df = df.fillna("Unknown")

# %%
df.shape
# Out:
# (53718, 39)

# %%
df.to_csv("../Data/weather_data.csv")
