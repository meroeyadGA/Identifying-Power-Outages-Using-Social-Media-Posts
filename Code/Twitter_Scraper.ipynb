# %% [markdown]
# # Twitter scraping

# %%
# Install Twitter Scraper
# !pip install twitterscraper

# %%
from twitterscraper import query_tweets
import pandas as pd
import datetime, time
# Out:
# INFO: {'User-Agent': 'Opera/9.80 (X11; Linux i686; Ubuntu/14.10) Presto/2.12.388 Version/12.16'}

# %%
# initialize a time counter
t0 = time.time()

# create a list of locations to scrape twitter in
locations = ["Alabama","Alaska","Arizona","Arkansas","California","Colorado",
  "Connecticut","Delaware","Florida","Georgia","Hawaii","Idaho","Illinois",
  "Indiana","Iowa","Kansas","Kentucky","Louisiana","Maine","Maryland",
  "Massachusetts","Michigan","Minnesota","Mississippi","Missouri","Montana",
  "Nebraska","Nevada","New Hampshire","New Jersey","New Mexico","New York",
  "North Carolina","North Dakota","Ohio","Oklahoma","Oregon","Pennsylvania",
  "Rhode Island","South Carolina","South Dakota","Tennessee","Texas","Utah",
  "Vermont","Virginia","Washington","West Virginia","Wisconsin","Wyoming", "District of Columbia"]

# set empty lists that we will fill with tweet data
text = []
locs = []
usernames = []
times = []
rt = []
likes = []

# loop through each place in the locations list
for place in locations:
    
    # scrape twitter for tweets containing certain keywords 
    query_string = f'"power outage" OR "power is out" OR "power\'s out" OR "blackouts" OR "blackout" -"video game" OR "power failure" OR "power failures" OR "no electricity" OR "power shortage" OR "electrical failure" OR "power loss" OR "power cuts" OR "power cut" OR "power went out" OR "power interuption" OR "brownout" OR "power goes out" OR "brownouts" OR "without power" near:"{place}" within:15mi -filter:retweets'
    list_of_tweets = query_tweets(query_string,
                            begindate = datetime.date(2014,1,1),
                            enddate = datetime.date(2019,12,31),
                            poolsize = 2,
                            lang="en"
                           )
    
    # loop through each tweet to grab data and append the data to their respective lists
    for tweet in list_of_tweets:
        locs.append(place)
        text.append(tweet.text)
        usernames.append(tweet.username)
        times.append(tweet.timestamp)
        rt.append(tweet.retweets)
        likes.append(tweet.likes)

# build the dataframe 
df = pd.DataFrame({
    'tweet': text,
    'location': locs,
    'user_name': usernames,
    'time_stamp': times,
    'num_retweets': rt,
    'num_likes': likes
})

print((time.time()-t0)/60)
# Out:
# INFO: queries: ['"power outage" OR "power is out" OR "power\'s out" OR "blackouts" OR "blackout" -"video game" OR "power failure" OR "power failures" OR "no electricity" OR "power shortage" OR "electrical failure" OR "power loss" OR "power cuts" OR "power cut" OR "power went out" OR "power interuption" OR "brownout" OR "power goes out" OR "brownouts" OR "without power" near:"Alabama" within:15mi -filter:retweets since:2014-01-01 until:2016-12-31', '"power outage" OR "power is out" OR "power\'s out" OR "blackouts" OR "blackout" -"video game" OR "power failure" OR "power failures" OR "no electricity" OR "power shortage" OR "electrical failure" OR "power loss" OR "power cuts" OR "power cut" OR "power went out" OR "power interuption" OR "brownout" OR "power goes out" OR "brownouts" OR "without power" near:"Alabama" within:15mi -filter:retweets since:2016-12-31 until:2019-12-31']
# INFO: Querying "power outage" OR "power is out" OR "power's out" OR "blackouts" OR "blackout" -"video game" OR "power failure" OR "power failures" OR "no electricity" OR "power shortage" OR "electrical failure" OR "power loss" OR "power cuts" OR "power cut" OR "power went out" OR "power interuption" OR "brownout" OR "power goes out" OR "brownouts" OR "without power" near:"Alabama" within:15mi -filter:retweets since:2014-01-01 until:2016-12-31
# INFO: Querying "power outage" OR "power is out" OR "power's out" OR "blackouts" OR "blackout" -"video game" OR "power failure" OR "power failures" OR "no electricity" OR "power shortage" OR "electrical failure" OR "power loss" OR "power cuts" OR "power cut" OR "power went out" OR "power interuption" OR "brownout" OR "power goes out" OR "brownouts" OR "without power" near:"Alabama" within:15mi -filter:retweets since:2016-12-31 until:2019-12-31
# INFO: Scraping tweets from https://twitter.com/search?f=tweets&vertical=default&q="power%20outage"%20OR%20"power%20is%20out"%20OR%20"power's%20out"%20OR%20"blackouts"%20OR%20"blackout"%20-"video%20game"%20OR%20"power%20failure"%20OR%20"power%20failures"%20OR%20"no%20electricity"%20OR%20"power%20shortage"%20OR%20"electrical%20failure"%20OR%20"power%20loss"%20OR%20"power%20cuts"%20OR%20"power%20cut"%20OR%20"power%20went%20out"%20OR%20"power%20interuption"%20OR%20"brownout"%20OR%20"power%20goes%20out"%20OR%20"brownouts"%20OR%20"without%20power"%20near%3A"Alabama"%20within%3A15mi%20-filter%3Aretweets%20since%3A2014-01-01%20until%3A2016-12-31&l=en
# INFO: Scraping tweets from https://twitter.com/search?f=tweets&vertical=default&q="power%20outage"%20OR%20"power%20is%20out"%20OR%20"power's%20out"%20OR%20"blackouts"%20OR%20"blackout"%20-"video%20game"%20OR%20"power%20failure"%20OR%20"power%20failures"%20OR%20"no%20electricity"%20OR%20"power%20shortage"%20OR%20"electrical%20failure"%20OR%20"power%20loss"%20OR%20"power%20cuts"%20OR%20"power%20cut"%20OR%20"power%20went%20out"%20OR%20"power%20interuption"%20OR%20"brownout"%20OR%20"power%20goes%20out"%20OR%20"brownouts"%20OR%20"without%20power"%20near%3A"Alabama"%20within%3A15mi%20-filter%3Aretweets%20since%3A2016-12-31%20until%3A2019-12-31&l=en
# INFO: Using proxy 119.192.195.83:443
# INFO: Using proxy 119.192.195.83:443
# INFO: Retrying... (Attempts left: 50)
# INFO: Scraping tweets from https://twitter.com/search?f=tweets&vertical=default&q="power%20outage"%20OR%20"power%20is%20out"%20OR%20"power's%20out"%20OR%20"blackouts"%20OR%20"blackout"%20-"video%20game"%20OR%20"power%20failure"%20OR%20"power%20failures"%20OR%20"no%20electricity"%20OR%20"power%20shortage"%20OR%20"electrical%20failure"%20OR%20"power%20loss"%20OR%20"power%20cuts"%20OR%20"power%20cut"%20OR%20"power%20went%20out"%20OR%20"power%20interuption"%20OR%20"brownout"%20OR%20"power%20goes%20out"%20OR%20"brownouts"%20OR%20"without%20power"%20near%3A"Alabama"%20within%3A15mi%20-filter%3Aretweets%20since%3A2014-01-01%20until%3A2016-12-31&l=en
# INFO: Using proxy 89.248.244.182:8080
# INFO: Scraping tweets from https://twitter.com/i/search/timeline?f=tweets&vertical=default&include_available_features=1&include_entities=1&reset_error_state=false&src=typd&max_position=TWEET-1188639771049902080-1190028572162957314&q="power%20outage"%20OR%20"power%20is%20out"%20OR%20"power's%20out"%20OR%20"blackouts"%20OR%20"blackout"%20-"video%20game"%20OR%20"power%20failure"%20OR%20"power%20failures"%20OR%20"no%20electricity"%20OR%20"power%20shortage"%20OR%20"electrical%20failure"%20OR%20"power%20loss"%20OR%20"power%20cuts"%20OR%20"power%20cut"%20OR%20"power%20went%20out"%20OR%20"power%20interuption"%20OR%20"brownout"%20OR%20"power%20goes%20out"%20OR%20"brownouts"%20OR%20"without%20power"%20near%3A"Alabama"%20within%3A15mi%20-filter%3Aretweets%20since%3A2016-12-31%20until%3A2019-12-31&l=en
# INFO: Using proxy 89.248.244.182:8080
# INFO: Scraping tweets from https://twitter.com/i/search/timeline?f=tweets&vertical=default&include_available_features=1&include_entities=1&reset_error_state=false&src=typd&max_position=thGAVUV0VFVBaAgKb13uTy_iAWhIC1xc2r6oMhEjUAFQAlAFUAFQAA&q="power%20outage"%20OR%20"power%20is%20out"%20OR%20"power's%20out"%20OR%20"blackouts"%20OR%20"blackout"%20-"video%20game"%20OR%20"power%20failure"%20OR%20"power%20failures"%20OR%20"no%20electricity"%20OR%20"power%20shortage"%20OR%20"electrical%20failure"%20OR%20"power%20loss"%20OR%20"power%20cuts"%20OR%20"power%20cut"%20OR%20"power%20went%20out"%20OR%20"power%20interuption"%20OR%20"brownout"%20OR%20"power%20goes%20out"%20OR%20"brownouts"%20OR%20"without%20power"%20near%3A"Alabama"%20within%3A15mi%20-filter%3Aretweets%20since%3A2016-12-31%20until%3A2019-12-31&l=en
# INFO: Using proxy 213.226.11.149:41878
# INFO: Scraping tweets from https://twitter.com/i/search/timeline?f=tweets&vertical=default&include_available_features=1&include_entities=1&reset_error_state=false&src=typd&max_position=TWEET-783349603387248643-783349603387248643&q="power%20outage"%20OR%20"power%20is%20out"%20OR%20"power's%20out"%20OR%20"blackouts"%20OR%20"blackout"%20-"video%20game"%20OR%20"power%20failure"%20OR%20"power%20failures"%20OR%20"no%20electricity"%20OR%20"power%20shortage"%20OR%20"electrical%20failure"%20OR%20"power%20loss"%20OR%20"power%20cuts"%20OR%20"power%20cut"%20OR%20"power%20went%20out"%20OR%20"power%20interuption"%20OR%20"brownout"%20OR%20"power%20goes%20out"%20OR%20"brownouts"%20OR%20"without%20power"%20near%3A"Alabama"%20within%3A15mi%20-filter%3Aretweets%20since%3A2014-01-01%20until%3A2016-12-31&l=en
# INFO: Using proxy 213.226.11.149:41878
# INFO: Scraping tweets from https://twitter.com/i/search/timeline?f=tweets&vertical=default&include_available_features=1&include_entities=1&reset_error_state=false&src=typd&max_position=thGAVUV0VFVBaCgLbFhPeK-SAWhIC1xc2r6oMhEjUAFQAlAFUAFQAA&q="power%20outage"%20OR%20"power%20is%20out"%20OR%20"power's%20out"%20OR%20"blackouts"%20OR%20"blackout"%20-"video%20game"%20OR%20"power%20failure"%20OR%20"power%20failures"%20OR%20"no%20electricity"%20OR%20"power%20shortage"%20OR%20"electrical%20failure"%20OR%20"power%20loss"%20OR%20"power%20cuts"%20OR%20"power%20cut"%20OR%20"power%20went%20out"%20OR%20"power%20interuption"%20OR%20"brownout"%20OR%20"power%20goes%20out"%20OR%20"brownouts"%20OR%20"without%20power"%20near%3A"Alabama"%20within%3A15mi%20-filter%3Aretweets%20since%3A2016-12-31%20until%3A2019-12-31&l=en
# INFO: Using proxy 176.9.75.42:8080
# INFO: Scraping tweets from https://twitter.com/i/search/timeline?f=tweets&vertical=default&include_available_features=1&include_entities=1&reset_error_state=false&src=typd&max_position=thGAVUV0VFVBaGwLjNi5SC3xUWhsC4zYuUgt8VEjUAFQAlAFUAFQAA&q="power%20outage"%20OR%20"power%20is%20out"%20OR%20"power's%20out"%20OR%20"blackouts"%20OR%20"blackout"%20-"video%20game"%20OR%20"power%20failure"%20OR%20"power%20failures"%20OR%20"no%20electricity"%20OR%20"power%20shortage"%20OR%20"electrical%20failure"%20OR%20"power%20loss"%20OR%20"power%20cuts"%20OR%20"power%20cut"%20OR%20"power%20went%20out"%20OR%20"power%20interuption"%20OR%20"brownout"%20OR%20"power%20goes%20out"%20OR%20"brownouts"%20OR%20"without%20power"%20near%3A"Alabama"%20within%3A15mi%20-filter%3Aretweets%20since%3A2014-01-01%20until%3A2016-12-31&l=en
# INFO: Using proxy 176.9.75.42:8080
# INFO: Twitter returned : 'has_more_items'
# INFO: Got 60 tweets for "power%20outage"%20OR%20"power%20is%20out"%20OR%20"power's%20out"%20OR%20"blackouts"%20OR%20"blackout"%20-"video%20game"%20OR%20"power%20failure"%20OR%20"power%20failures"%20OR%20"no%20electricity"%20OR%20"power%20shortage"%20OR%20"electrical%20failure"%20OR%20"power%20loss"%20OR%20"power%20cuts"%20OR%20"power%20cut"%20OR%20"power%20went%20out"%20OR%20"power%20interuption"%20OR%20"brownout"%20OR%20"power%20goes%20out"%20OR%20"brownouts"%20OR%20"without%20power"%20near%3A"Alabama"%20within%3A15mi%20-filter%3Aretweets%20since%3A2016-12-31%20until%3A2019-12-31.
# INFO: Got 60 tweets (60 new).
# INFO: Twitter returned : 'has_more_items'
# INFO: Got 2 tweets for "power%20outage"%20OR%20"power%20is%20out"%20OR%20"power's%20out"%20OR%20"blackouts"%20OR%20"blackout"%20-"video%20game"%20OR%20"power%20failure"%20OR%20"power%20failures"%20OR%20"no%20electricity"%20OR%20"power%20shortage"%20OR%20"electrical%20failure"%20OR%20"power%20loss"%20OR%20"power%20cuts"%20OR%20"power%20cut"%20OR%20"power%20went%20out"%20OR%20"power%20interuption"%20OR%20"brownout"%20OR%20"power%20goes%20out"%20OR%20"brownouts"%20OR%20"without%20power"%20near%3A"Alabama"%20within%3A15mi%20-filter%3Aretweets%20since%3A2014-01-01%20until%3A2016-12-31.
# INFO: Got 62 tweets (2 new).
# INFO: queries: ['"power outage" OR "power is out" OR "power\'s out" OR "blackouts" OR "blackout" -"video game" OR "power failure" OR "power failures" OR "no electricity" OR "power shortage" OR "electrical failure" OR "power loss" OR "power cuts" OR "power cut" OR "power went out" OR "power interuption" OR "brownout" OR "power goes out" OR "brownouts" OR "without power" near:"Alaska" within:15mi -filter:retweets since:2014-01-01 until:2016-12-31', '"power outage" OR "power is out" OR "power\'s out" OR "blackouts" OR "blackout" -"video game" OR "power failure" OR "power failures" OR "no electricity" OR "power shortage" OR "electrical failure" OR "power loss" OR "power cuts" OR "power cut" OR "power went out" OR "power interuption" OR "brownout" OR "power goes out" OR "brownouts" OR "without power" near:"Alaska" within:15mi -filter:retweets since:2016-12-31 until:2019-12-31']
# INFO: Querying "power outage" OR "power is out" OR "power's out" OR "blackouts" OR "blackout" -"video game" OR "power failure" OR "power failures" OR "no electricity" OR "power shortage" OR "electrical failure" OR "power loss" OR "power cuts" OR "power cut" OR "power went out" OR "power interuption" OR "brownout" OR "power goes out" OR "brownouts" OR "without power" near:"Alaska" within:15mi -filter:retweets since:2014-01-01 until:2016-12-31
# INFO: Querying "power outage" OR "power is out" OR "power's out" OR "blackouts" OR "blackout" -"video game" OR "power failure" OR "power failures" OR "no electricity" OR "power shortage" OR "electrical failure" OR "power loss" OR "power cuts" OR "power cut" OR "power went out" OR "power interuption" OR "brownout" OR "power goes out" OR "brownouts" OR "without power" near:"Alaska" within:15mi -filter:retweets since:2016-12-31 until:2019-12-31
# INFO: Scraping tweets from https://twitter.com/search?f=tweets&vertical=default&q="power%20outage"%20OR%20"power%20is%20out"%20OR%20"power's%20out"%20OR%20"blackouts"%20OR%20"blackout"%20-"video%20game"%20OR%20"power%20failure"%20OR%20"power%20failures"%20OR%20"no%20electricity"%20OR%20"power%20shortage"%20OR%20"electrical%20failure"%20OR%20"power%20loss"%20OR%20"power%20cuts"%20OR%20"power%20cut"%20OR%20"power%20went%20out"%20OR%20"power%20interuption"%20OR%20"brownout"%20OR%20"power%20goes%20out"%20OR%20"brownouts"%20OR%20"without%20power"%20near%3A"Alaska"%20within%3A15mi%20-filter%3Aretweets%20since%3A2014-01-01%20until%3A2016-12-31&l=en
# INFO: Using proxy 119.192.195.83:443
# INFO: Scraping tweets from https://twitter.com/search?f=tweets&vertical=default&q="power%20outage"%20OR%20"power%20is%20out"%20OR%20"power's%20out"%20OR%20"blackouts"%20OR%20"blackout"%20-"video%20game"%20OR%20"power%20failure"%20OR%20"power%20failures"%20OR%20"no%20electricity"%20OR%20"power%20shortage"%20OR%20"electrical%20failure"%20OR%20"power%20loss"%20OR%20"power%20cuts"%20OR%20"power%20cut"%20OR%20"power%20went%20out"%20OR%20"power%20interuption"%20OR%20"brownout"%20OR%20"power%20goes%20out"%20OR%20"brownouts"%20OR%20"without%20power"%20near%3A"Alaska"%20within%3A15mi%20-filter%3Aretweets%20since%3A2016-12-31%20until%3A2019-12-31&l=en
# INFO: Using proxy 119.192.195.83:443
# INFO: Scraping tweets from https://twitter.com/i/search/timeline?f=tweets&vertical=default&include_available_features=1&include_entities=1&reset_error_state=false&src=typd&max_position=TWEET-517443708825116672-577883856965099520&q="power%20outage"%20OR%20"power%20is%20out"%20OR%20"power's%20out"%20OR%20"blackouts"%20OR%20"blackout"%20-"video%20game"%20OR%20"power%20failure"%20OR%20"power%20failures"%20OR%20"no%20electricity"%20OR%20"power%20shortage"%20OR%20"electrical%20failure"%20OR%20"power%20loss"%20OR%20"power%20cuts"%20OR%20"power%20cut"%20OR%20"power%20went%20out"%20OR%20"power%20interuption"%20OR%20"brownout"%20OR%20"power%20goes%20out"%20OR%20"brownouts"%20OR%20"without%20power"%20near%3A"Alaska"%20within%3A15mi%20-filter%3Aretweets%20since%3A2014-01-01%20until%3A2016-12-31&l=en
# INFO: Using proxy 89.248.244.182:8080
# INFO: Scraping tweets from https://twitter.com/i/search/timeline?f=tweets&vertical=default&include_available_features=1&include_entities=1&reset_error_state=false&src=typd&max_position=TWEET-1187260128162144256-1189741265165967360&q="power%20outage"%20OR%20"power%20is%20out"%20OR%20"power's%20out"%20OR%20"blackouts"%20OR%20"blackout"%20-"video%20game"%20OR%20"power%20failure"%20OR%20"power%20failures"%20OR%20"no%20electricity"%20OR%20"power%20shortage"%20OR%20"electrical%20failure"%20OR%20"power%20loss"%20OR%20"power%20cuts"%20OR%20"power%20cut"%20OR%20"power%20went%20out"%20OR%20"power%20interuption"%20OR%20"brownout"%20OR%20"power%20goes%20out"%20OR%20"brownouts"%20OR%20"without%20power"%20near%3A"Alaska"%20within%3A15mi%20-filter%3Aretweets%20since%3A2016-12-31%20until%3A2019-12-31&l=en
# INFO: Using proxy 89.248.244.182:8080
# INFO: Scraping tweets from https://twitter.com/i/search/timeline?f=tweets&vertical=default&include_available_features=1&include_entities=1&reset_error_state=false&src=typd&max_position=thGAVUV0VFVBaAgMLwx8Sf8w0WgICz_cuTh4UQEjUAFQAlAFUAFQAA&q="power%20outage"%20OR%20"power%20is%20out"%20OR%20"power's%20out"%20OR%20"blackouts"%20OR%20"blackout"%20-"video%20game"%20OR%20"power%20failure"%20OR%20"power%20failures"%20OR%20"no%20electricity"%20OR%20"power%20shortage"%20OR%20"electrical%20failure"%20OR%20"power%20loss"%20OR%20"power%20cuts"%20OR%20"power%20cut"%20OR%20"power%20went%20out"%20OR%20"power%20interuption"%20OR%20"brownout"%20OR%20"power%20goes%20out"%20OR%20"brownouts"%20OR%20"without%20power"%20near%3A"Alaska"%20within%3A15mi%20-filter%3Aretweets%20since%3A2014-01-01%20until%3A2016-12-31&l=en
# INFO: Using proxy 213.226.11.149:41878
# INFO: Scraping tweets from https://twitter.com/i/search/timeline?f=tweets&vertical=default&include_available_features=1&include_entities=1&reset_error_state=false&src=typd&max_position=thGAVUV0VFVBaAgLex-rL_-SAWgIC7zZHY54IhEjUAFQAlAFUAFQAA&q="power%20outage"%20OR%20"power%20is%20out"%20OR%20"power's%20out"%20OR%20"blackouts"%20OR%20"blackout"%20-"video%20game"%20OR%20"power%20failure"%20OR%20"power%20failures"%20OR%20"no%20electricity"%20OR%20"power%20shortage"%20OR%20"electrical%20failure"%20OR%20"power%20loss"%20OR%20"power%20cuts"%20OR%20"power%20cut"%20OR%20"power%20went%20out"%20OR%20"power%20interuption"%20OR%20"brownout"%20OR%20"power%20goes%20out"%20OR%20"brownouts"%20OR%20"without%20power"%20near%3A"Alaska"%20within%3A15mi%20-filter%3Aretweets%20since%3A2016-12-31%20until%3A2019-12-31&l=en
# INFO: Using proxy 213.226.11.149:41878
# INFO: Scraping tweets from https://twitter.com/i/search/timeline?f=tweets&vertical=default&include_available_features=1&include_entities=1&reset_error_state=false&src=typd&max_position=thGAVUV0VFVBaAwJLUtvzvgwwWgICz_cuTh4UQEjUAFQAlAFUAFQAA&q="power%20outage"%20OR%20"power%20is%20out"%20OR%20"power's%20out"%20OR%20"blackouts"%20OR%20"blackout"%20-"video%20game"%20OR%20"power%20failure"%20OR%20"power%20failures"%20OR%20"no%20electricity"%20OR%20"power%20shortage"%20OR%20"electrical%20failure"%20OR%20"power%20loss"%20OR%20"power%20cuts"%20OR%20"power%20cut"%20OR%20"power%20went%20out"%20OR%20"power%20interuption"%20OR%20"brownout"%20OR%20"power%20goes%20out"%20OR%20"brownouts"%20OR%20"without%20power"%20near%3A"Alaska"%20within%3A15mi%20-filter%3Aretweets%20since%3A2014-01-01%20until%3A2016-12-31&l=en
# INFO: Using proxy 176.9.75.42:8080
# INFO: Twitter returned : 'has_more_items'
# INFO: Got 11 tweets for "power%20outage"%20OR%20"power%20is%20out"%20OR%20"power's%20out"%20OR%20"blackouts"%20OR%20"blackout"%20-"video%20game"%20OR%20"power%20failure"%20OR%20"power%20failures"%20OR%20"no%20electricity"%20OR%20"power%20shortage"%20OR%20"electrical%20failure"%20OR%20"power%20loss"%20OR%20"power%20cuts"%20OR%20"power%20cut"%20OR%20"power%20went%20out"%20OR%20"power%20interuption"%20OR%20"brownout"%20OR%20"power%20goes%20out"%20OR%20"brownouts"%20OR%20"without%20power"%20near%3A"Alaska"%20within%3A15mi%20-filter%3Aretweets%20since%3A2014-01-01%20until%3A2016-12-31.
# INFO: Got 11 tweets (11 new).
# INFO: Scraping tweets from https://twitter.com/i/search/timeline?f=tweets&vertical=default&include_available_features=1&include_entities=1&reset_error_state=false&src=typd&max_position=thGAVUV0VFVBaAwLTV3Mqm-CAWgIC7zZHY54IhEjUAFQAlAFUAFQAA&q="power%20outage"%20OR%20"power%20is%20out"%20OR%20"power's%20out"%20OR%20"blackouts"%20OR%20"blackout"%20-"video%20game"%20OR%20"power%20failure"%20OR%20"power%20failures"%20OR%20"no%20electricity"%20OR%20"power%20shortage"%20OR%20"electrical%20failure"%20OR%20"power%20loss"%20OR%20"power%20cuts"%20OR%20"power%20cut"%20OR%20"power%20went%20out"%20OR%20"power%20interuption"%20OR%20"brownout"%20OR%20"power%20goes%20out"%20OR%20"brownouts"%20OR%20"without%20power"%20near%3A"Alaska"%20within%3A15mi%20-filter%3Aretweets%20since%3A2016-12-31%20until%3A2019-12-31&l=en
# INFO: Using proxy 176.9.75.42:8080
# INFO: Twitter returned : 'has_more_items'
# INFO: Got 43 tweets for "power%20outage"%20OR%20"power%20is%20out"%20OR%20"power's%20out"%20OR%20"blackouts"%20OR%20"blackout"%20-"video%20game"%20OR%20"power%20failure"%20OR%20"power%20failures"%20OR%20"no%20electricity"%20OR%20"power%20shortage"%20OR%20"electrical%20failure"%20OR%20"power%20loss"%20OR%20"power%20cuts"%20OR%20"power%20cut"%20OR%20"power%20went%20out"%20OR%20"power%20interuption"%20OR%20"brownout"%20OR%20"power%20goes%20out"%20OR%20"brownouts"%20OR%20"without%20power"%20near%3A"Alaska"%20within%3A15mi%20-filter%3Aretweets%20since%3A2016-12-31%20until%3A2019-12-31.
# INFO: Got 54 tweets (43 new).
# INFO: queries: ['"power outage" OR "power is out" OR "power\'s out" OR "blackouts" OR "blackout" -"video game" OR "power failure" OR "power failures" OR "no electricity" OR "power shortage" OR "electrical failure" OR "power loss" OR "power cuts" OR "power cut" OR "power went out" OR "power interuption" OR "brownout" OR "power goes out" OR "brownouts" OR "without power" near:"Arizona" within:15mi -filter:retweets since:2014-01-01 until:2016-12-31', '"power outage" OR "power is out" OR "power\'s out" OR "blackouts" OR "blackout" -"video game" OR "power failure" OR "power failures" OR "no electricity" OR "power shortage" OR "electrical failure" OR "power loss" OR "power cuts" OR "power cut" OR "power went out" OR "power interuption" OR "brownout" OR "power goes out" OR "brownouts" OR "without power" near:"Arizona" within:15mi -filter:retweets since:2016-12-31 until:2019-12-31']
# INFO: Querying "power outage" OR "power is out" OR "power's out" OR "blackouts" OR "blackout" -"video game" OR "power failure" OR "power failures" OR "no electricity" OR "power shortage" OR "electrical failure" OR "power loss" OR "power cuts" OR "power cut" OR "power went out" OR "power interuption" OR "brownout" OR "power goes out" OR "brownouts" OR "without power" near:"Arizona" within:15mi -filter:retweets since:2014-01-01 until:2016-12-31
# INFO: Querying "power outage" OR "power is out" OR "power's out" OR "blackouts" OR "blackout" -"video game" OR "power failure" OR "power failures" OR "no electricity" OR "power shortage" OR "electrical failure" OR "power loss" OR "power cuts" OR "power cut" OR "power went out" OR "power interuption" OR "brownout" OR "power goes out" OR "brownouts" OR "without power" near:"Arizona" within:15mi -filter:retweets since:2016-12-31 until:2019-12-31
# INFO: Scraping tweets from https://twitter.com/search?f=tweets&vertical=default&q="power%20outage"%20OR%20"power%20is%20out"%20OR%20"power's%20out"%20OR%20"blackouts"%20OR%20"blackout"%20-"video%20game"%20OR%20"power%20failure"%20OR%20"power%20failures"%20OR%20"no%20electricity"%20OR%20"power%20shortage"%20OR%20"electrical%20failure"%20OR%20"power%20loss"%20OR%20"power%20cuts"%20OR%20"power%20cut"%20OR%20"power%20went%20out"%20OR%20"power%20interuption"%20OR%20"brownout"%20OR%20"power%20goes%20out"%20OR%20"brownouts"%20OR%20"without%20power"%20near%3A"Arizona"%20within%3A15mi%20-filter%3Aretweets%20since%3A2014-01-01%20until%3A2016-12-31&l=en
# INFO: Using proxy 119.192.195.83:443
# INFO: Scraping tweets from https://twitter.com/search?f=tweets&vertical=default&q="power%20outage"%20OR%20"power%20is%20out"%20OR%20"power's%20out"%20OR%20"blackouts"%20OR%20"blackout"%20-"video%20game"%20OR%20"power%20failure"%20OR%20"power%20failures"%20OR%20"no%20electricity"%20OR%20"power%20shortage"%20OR%20"electrical%20failure"%20OR%20"power%20loss"%20OR%20"power%20cuts"%20OR%20"power%20cut"%20OR%20"power%20went%20out"%20OR%20"power%20interuption"%20OR%20"brownout"%20OR%20"power%20goes%20out"%20OR%20"brownouts"%20OR%20"without%20power"%20near%3A"Arizona"%20within%3A15mi%20-filter%3Aretweets%20since%3A2016-12-31%20until%3A2019-12-31&l=en
# INFO: Using proxy 119.192.195.83:443
# INFO: Retrying... (Attempts left: 50)
# INFO: Scraping tweets from https://twitter.com/search?f=tweets&vertical=default&q="power%20outage"%20OR%20"power%20is%20out"%20OR%20"power's%20out"%20OR%20"blackouts"%20OR%20"blackout"%20-"video%20game"%20OR%20"power%20failure"%20OR%20"power%20failures"%20OR%20"no%20electricity"%20OR%20"power%20shortage"%20OR%20"electrical%20failure"%20OR%20"power%20loss"%20OR%20"power%20cuts"%20OR%20"power%20cut"%20OR%20"power%20went%20out"%20OR%20"power%20interuption"%20OR%20"brownout"%20OR%20"power%20goes%20out"%20OR%20"brownouts"%20OR%20"without%20power"%20near%3A"Arizona"%20within%3A15mi%20-filter%3Aretweets%20since%3A2014-01-01%20until%3A2016-12-31&l=en
# INFO: Using proxy 89.248.244.182:8080
# INFO: Scraping tweets from https://twitter.com/i/search/timeline?f=tweets&vertical=default&include_available_features=1&include_entities=1&reset_error_state=false&src=typd&max_position=TWEET-1188094884290289664-1190011288455274496&q="power%20outage"%20OR%20"power%20is%20out"%20OR%20"power's%20out"%20OR%20"blackouts"%20OR%20"blackout"%20-"video%20game"%20OR%20"power%20failure"%20OR%20"power%20failures"%20OR%20"no%20electricity"%20OR%20"power%20shortage"%20OR%20"electrical%20failure"%20OR%20"power%20loss"%20OR%20"power%20cuts"%20OR%20"power%20cut"%20OR%20"power%20went%20out"%20OR%20"power%20interuption"%20OR%20"brownout"%20OR%20"power%20goes%20out"%20OR%20"brownouts"%20OR%20"without%20power"%20near%3A"Arizona"%20within%3A15mi%20-filter%3Aretweets%20since%3A2016-12-31%20until%3A2019-12-31&l=en
# INFO: Using proxy 89.248.244.182:8080
# INFO: Retrying... (Attempts left: 49)
# INFO: Scraping tweets from https://twitter.com/search?f=tweets&vertical=default&q="power%20outage"%20OR%20"power%20is%20out"%20OR%20"power's%20out"%20OR%20"blackouts"%20OR%20"blackout"%20-"video%20game"%20OR%20"power%20failure"%20OR%20"power%20failures"%20OR%20"no%20electricity"%20OR%20"power%20shortage"%20OR%20"electrical%20failure"%20OR%20"power%20loss"%20OR%20"power%20cuts"%20OR%20"power%20cut"%20OR%20"power%20went%20out"%20OR%20"power%20interuption"%20OR%20"brownout"%20OR%20"power%20goes%20out"%20OR%20"brownouts"%20OR%20"without%20power"%20near%3A"Arizona"%20within%3A15mi%20-filter%3Aretweets%20since%3A2014-01-01%20until%3A2016-12-31&l=en
# INFO: Using proxy 213.226.11.149:41878
# INFO: Scraping tweets from https://twitter.com/i/search/timeline?f=tweets&vertical=default&include_available_features=1&include_entities=1&reset_error_state=false&src=typd&max_position=thGAVUV0VFVBaAgKeZlID7_CAWgICn8ce94oMhEjUAFQAlAFUAFQAA&q="power%20outage"%20OR%20"power%20is%20out"%20OR%20"power's%20out"%20OR%20"blackouts"%20OR%20"blackout"%20-"video%20game"%20OR%20"power%20failure"%20OR%20"power%20failures"%20OR%20"no%20electricity"%20OR%20"power%20shortage"%20OR%20"electrical%20failure"%20OR%20"power%20loss"%20OR%20"power%20cuts"%20OR%20"power%20cut"%20OR%20"power%20went%20out"%20OR%20"power%20interuption"%20OR%20"brownout"%20OR%20"power%20goes%20out"%20OR%20"brownouts"%20OR%20"without%20power"%20near%3A"Arizona"%20within%3A15mi%20-filter%3Aretweets%20since%3A2016-12-31%20until%3A2019-12-31&l=en
# INFO: Using proxy 213.226.11.149:41878
# INFO: Retrying... (Attempts left: 48)
# INFO: Scraping tweets from https://twitter.com/search?f=tweets&vertical=default&q="power%20outage"%20OR%20"power%20is%20out"%20OR%20"power's%20out"%20OR%20"blackouts"%20OR%20"blackout"%20-"video%20game"%20OR%20"power%20failure"%20OR%20"power%20failures"%20OR%20"no%20electricity"%20OR%20"power%20shortage"%20OR%20"electrical%20failure"%20OR%20"power%20loss"%20OR%20"power%20cuts"%20OR%20"power%20cut"%20OR%20"power%20went%20out"%20OR%20"power%20interuption"%20OR%20"brownout"%20OR%20"power%20goes%20out"%20OR%20"brownouts"%20OR%20"without%20power"%20near%3A"Arizona"%20within%3A15mi%20-filter%3Aretweets%20since%3A2014-01-01%20until%3A2016-12-31&l=en
# INFO: Using proxy 176.9.75.42:8080
# INFO: Scraping tweets from https://twitter.com/i/search/timeline?f=tweets&vertical=default&include_available_features=1&include_entities=1&reset_error_state=false&src=typd&max_position=thGAVUV0VFVBaEwKDt2MSx-iAWgICn8ce94oMhEjUAFQAlAFUAFQAA&q="power%20outage"%20OR%20"power%20is%20out"%20OR%20"power's%20out"%20OR%20"blackouts"%20OR%20"blackout"%20-"video%20game"%20OR%20"power%20failure"%20OR%20"power%20failures"%20OR%20"no%20electricity"%20OR%20"power%20shortage"%20OR%20"electrical%20failure"%20OR%20"power%20loss"%20OR%20"power%20cuts"%20OR%20"power%20cut"%20OR%20"power%20went%20out"%20OR%20"power%20interuption"%20OR%20"brownout"%20OR%20"power%20goes%20out"%20OR%20"brownouts"%20OR%20"without%20power"%20near%3A"Arizona"%20within%3A15mi%20-filter%3Aretweets%20since%3A2016-12-31%20until%3A2019-12-31&l=en
# INFO: Using proxy 176.9.75.42:8080
# INFO: Twitter returned : 'has_more_items'
# INFO: Got 45 tweets for "power%20outage"%20OR%20"power%20is%20out"%20OR%20"power's%20out"%20OR%20"blackouts"%20OR%20"blackout"%20-"video%20game"%20OR%20"power%20failure"%20OR%20"power%20failures"%20OR%20"no%20electricity"%20OR%20"power%20shortage"%20OR%20"electrical%20failure"%20OR%20"power%20loss"%20OR%20"power%20cuts"%20OR%20"power%20cut"%20OR%20"power%20went%20out"%20OR%20"power%20interuption"%20OR%20"brownout"%20OR%20"power%20goes%20out"%20OR%20"brownouts"%20OR%20"without%20power"%20near%3A"Arizona"%20within%3A15mi%20-filter%3Aretweets%20since%3A2016-12-31%20until%3A2019-12-31.
# INFO: Got 45 tweets (45 new).
# INFO: Retrying... (Attempts left: 47)
# INFO: Scraping tweets from https://twitter.com/search?f=tweets&vertical=default&q="power%20outage"%20OR%20"power%20is%20out"%20OR%20"power's%20out"%20OR%20"blackouts"%20OR%20"blackout"%20-"video%20game"%20OR%20"power%20failure"%20OR%20"power%20failures"%20OR%20"no%20electricity"%20OR%20"power%20shortage"%20OR%20"electrical%20failure"%20OR%20"power%20loss"%20OR%20"power%20cuts"%20OR%20"power%20cut"%20OR%20"power%20went%20out"%20OR%20"power%20interuption"%20OR%20"brownout"%20OR%20"power%20goes%20out"%20OR%20"brownouts"%20OR%20"without%20power"%20near%3A"Arizona"%20within%3A15mi%20-filter%3Aretweets%20since%3A2014-01-01%20until%3A2016-12-31&l=en
# INFO: Using proxy 202.57.35.74:37211
# INFO: Retrying... (Attempts left: 46)
# INFO: Scraping tweets from https://twitter.com/search?f=tweets&vertical=default&q="power%20outage"%20OR%20"power%20is%20out"%20OR%20"power's%20out"%20OR%20"blackouts"%20OR%20"blackout"%20-"video%20game"%20OR%20"power%20failure"%20OR%20"power%20failures"%20OR%20"no%20electricity"%20OR%20"power%20shortage"%20OR%20"electrical%20failure"%20OR%20"power%20loss"%20OR%20"power%20cuts"%20OR%20"power%20cut"%20OR%20"power%20went%20out"%20OR%20"power%20interuption"%20OR%20"brownout"%20OR%20"power%20goes%20out"%20OR%20"brownouts"%20OR%20"without%20power"%20near%3A"Arizona"%20within%3A15mi%20-filter%3Aretweets%20since%3A2014-01-01%20until%3A2016-12-31&l=en
# INFO: Using proxy 119.82.252.71:30506
# INFO: Retrying... (Attempts left: 45)
# INFO: Scraping tweets from https://twitter.com/search?f=tweets&vertical=default&q="power%20outage"%20OR%20"power%20is%20out"%20OR%20"power's%20out"%20OR%20"blackouts"%20OR%20"blackout"%20-"video%20game"%20OR%20"power%20failure"%20OR%20"power%20failures"%20OR%20"no%20electricity"%20OR%20"power%20shortage"%20OR%20"electrical%20failure"%20OR%20"power%20loss"%20OR%20"power%20cuts"%20OR%20"power%20cut"%20OR%20"power%20went%20out"%20OR%20"power%20interuption"%20OR%20"brownout"%20OR%20"power%20goes%20out"%20OR%20"brownouts"%20OR%20"without%20power"%20near%3A"Arizona"%20within%3A15mi%20-filter%3Aretweets%20since%3A2014-01-01%20until%3A2016-12-31&l=en
# INFO: Using proxy 125.27.10.243:58219
# INFO: Retrying... (Attempts left: 44)
# INFO: Scraping tweets from https://twitter.com/search?f=tweets&vertical=default&q="power%20outage"%20OR%20"power%20is%20out"%20OR%20"power's%20out"%20OR%20"blackouts"%20OR%20"blackout"%20-"video%20game"%20OR%20"power%20failure"%20OR%20"power%20failures"%20OR%20"no%20electricity"%20OR%20"power%20shortage"%20OR%20"electrical%20failure"%20OR%20"power%20loss"%20OR%20"power%20cuts"%20OR%20"power%20cut"%20OR%20"power%20went%20out"%20OR%20"power%20interuption"%20OR%20"brownout"%20OR%20"power%20goes%20out"%20OR%20"brownouts"%20OR%20"without%20power"%20near%3A"Arizona"%20within%3A15mi%20-filter%3Aretweets%20since%3A2014-01-01%20until%3A2016-12-31&l=en
# INFO: Using proxy 67.205.149.230:8080
# INFO: Retrying... (Attempts left: 43)
# INFO: Scraping tweets from https://twitter.com/search?f=tweets&vertical=default&q="power%20outage"%20OR%20"power%20is%20out"%20OR%20"power's%20out"%20OR%20"blackouts"%20OR%20"blackout"%20-"video%20game"%20OR%20"power%20failure"%20OR%20"power%20failures"%20OR%20"no%20electricity"%20OR%20"power%20shortage"%20OR%20"electrical%20failure"%20OR%20"power%20loss"%20OR%20"power%20cuts"%20OR%20"power%20cut"%20OR%20"power%20went%20out"%20OR%20"power%20interuption"%20OR%20"brownout"%20OR%20"power%20goes%20out"%20OR%20"brownouts"%20OR%20"without%20power"%20near%3A"Arizona"%20within%3A15mi%20-filter%3Aretweets%20since%3A2014-01-01%20until%3A2016-12-31&l=en
# INFO: Using proxy 5.196.132.124:3128
# INFO: Retrying... (Attempts left: 42)
# INFO: Scraping tweets from https://twitter.com/search?f=tweets&vertical=default&q="power%20outage"%20OR%20"power%20is%20out"%20OR%20"power's%20out"%20OR%20"blackouts"%20OR%20"blackout"%20-"video%20game"%20OR%20"power%20failure"%20OR%20"power%20failures"%20OR%20"no%20electricity"%20OR%20"power%20shortage"%20OR%20"electrical%20failure"%20OR%20"power%20loss"%20OR%20"power%20cuts"%20OR%20"power%20cut"%20OR%20"power%20went%20out"%20OR%20"power%20interuption"%20OR%20"brownout"%20OR%20"power%20goes%20out"%20OR%20"brownouts"%20OR%20"without%20power"%20near%3A"Arizona"%20within%3A15mi%20-filter%3Aretweets%20since%3A2014-01-01%20until%3A2016-12-31&l=en
# INFO: Using proxy 186.47.82.6:41430
# INFO: Retrying... (Attempts left: 41)
# INFO: Scraping tweets from https://twitter.com/search?f=tweets&vertical=default&q="power%20outage"%20OR%20"power%20is%20out"%20OR%20"power's%20out"%20OR%20"blackouts"%20OR%20"blackout"%20-"video%20game"%20OR%20"power%20failure"%20OR%20"power%20failures"%20OR%20"no%20electricity"%20OR%20"power%20shortage"%20OR%20"electrical%20failure"%20OR%20"power%20loss"%20OR%20"power%20cuts"%20OR%20"power%20cut"%20OR%20"power%20went%20out"%20OR%20"power%20interuption"%20OR%20"brownout"%20OR%20"power%20goes%20out"%20OR%20"brownouts"%20OR%20"without%20power"%20near%3A"Arizona"%20within%3A15mi%20-filter%3Aretweets%20since%3A2014-01-01%20until%3A2016-12-31&l=en
# INFO: Using proxy 175.100.18.45:60537
# INFO: Retrying... (Attempts left: 40)
# INFO: Scraping tweets from https://twitter.com/search?f=tweets&vertical=default&q="power%20outage"%20OR%20"power%20is%20out"%20OR%20"power's%20out"%20OR%20"blackouts"%20OR%20"blackout"%20-"video%20game"%20OR%20"power%20failure"%20OR%20"power%20failures"%20OR%20"no%20electricity"%20OR%20"power%20shortage"%20OR%20"electrical%20failure"%20OR%20"power%20loss"%20OR%20"power%20cuts"%20OR%20"power%20cut"%20OR%20"power%20went%20out"%20OR%20"power%20interuption"%20OR%20"brownout"%20OR%20"power%20goes%20out"%20OR%20"brownouts"%20OR%20"without%20power"%20near%3A"Arizona"%20within%3A15mi%20-filter%3Aretweets%20since%3A2014-01-01%20until%3A2016-12-31&l=en
# INFO: Using proxy 145.239.169.43:1080
# INFO: Retrying... (Attempts left: 39)
# INFO: Scraping tweets from https://twitter.com/search?f=tweets&vertical=default&q="power%20outage"%20OR%20"power%20is%20out"%20OR%20"power's%20out"%20OR%20"blackouts"%20OR%20"blackout"%20-"video%20game"%20OR%20"power%20failure"%20OR%20"power%20failures"%20OR%20"no%20electricity"%20OR%20"power%20shortage"%20OR%20"electrical%20failure"%20OR%20"power%20loss"%20OR%20"power%20cuts"%20OR%20"power%20cut"%20OR%20"power%20went%20out"%20OR%20"power%20interuption"%20OR%20"brownout"%20OR%20"power%20goes%20out"%20OR%20"brownouts"%20OR%20"without%20power"%20near%3A"Arizona"%20within%3A15mi%20-filter%3Aretweets%20since%3A2014-01-01%20until%3A2016-12-31&l=en
# INFO: Using proxy 145.239.81.69:3128
# INFO: Retrying... (Attempts left: 38)
# INFO: Scraping tweets from https://twitter.com/search?f=tweets&vertical=default&q="power%20outage"%20OR%20"power%20is%20out"%20OR%20"power's%20out"%20OR%20"blackouts"%20OR%20"blackout"%20-"video%20game"%20OR%20"power%20failure"%20OR%20"power%20failures"%20OR%20"no%20electricity"%20OR%20"power%20shortage"%20OR%20"electrical%20failure"%20OR%20"power%20loss"%20OR%20"power%20cuts"%20OR%20"power%20cut"%20OR%20"power%20went%20out"%20OR%20"power%20interuption"%20OR%20"brownout"%20OR%20"power%20goes%20out"%20OR%20"brownouts"%20OR%20"without%20power"%20near%3A"Arizona"%20within%3A15mi%20-filter%3Aretweets%20since%3A2014-01-01%20until%3A2016-12-31&l=en
# INFO: Using proxy 43.225.164.59:37193
# INFO: Retrying... (Attempts left: 37)
# INFO: Scraping tweets from https://twitter.com/search?f=tweets&vertical=default&q="power%20outage"%20OR%20"power%20is%20out"%20OR%20"power's%20out"%20OR%20"blackouts"%20OR%20"blackout"%20-"video%20game"%20OR%20"power%20failure"%20OR%20"power%20failures"%20OR%20"no%20electricity"%20OR%20"power%20shortage"%20OR%20"electrical%20failure"%20OR%20"power%20loss"%20OR%20"power%20cuts"%20OR%20"power%20cut"%20OR%20"power%20went%20out"%20OR%20"power%20interuption"%20OR%20"brownout"%20OR%20"power%20goes%20out"%20OR%20"brownouts"%20OR%20"without%20power"%20near%3A"Arizona"%20within%3A15mi%20-filter%3Aretweets%20since%3A2014-01-01%20until%3A2016-12-31&l=en
# INFO: Using proxy 174.138.54.49:8080
# INFO: Retrying... (Attempts left: 36)
# INFO: Scraping tweets from https://twitter.com/search?f=tweets&vertical=default&q="power%20outage"%20OR%20"power%20is%20out"%20OR%20"power's%20out"%20OR%20"blackouts"%20OR%20"blackout"%20-"video%20game"%20OR%20"power%20failure"%20OR%20"power%20failures"%20OR%20"no%20electricity"%20OR%20"power%20shortage"%20OR%20"electrical%20failure"%20OR%20"power%20loss"%20OR%20"power%20cuts"%20OR%20"power%20cut"%20OR%20"power%20went%20out"%20OR%20"power%20interuption"%20OR%20"brownout"%20OR%20"power%20goes%20out"%20OR%20"brownouts"%20OR%20"without%20power"%20near%3A"Arizona"%20within%3A15mi%20-filter%3Aretweets%20since%3A2014-01-01%20until%3A2016-12-31&l=en
# INFO: Using proxy 171.100.9.126:49163
# INFO: Retrying... (Attempts left: 35)
# INFO: Scraping tweets from https://twitter.com/search?f=tweets&vertical=default&q="power%20outage"%20OR%20"power%20is%20out"%20OR%20"power's%20out"%20OR%20"blackouts"%20OR%20"blackout"%20-"video%20game"%20OR%20"power%20failure"%20OR%20"power%20failures"%20OR%20"no%20electricity"%20OR%20"power%20shortage"%20OR%20"electrical%20failure"%20OR%20"power%20loss"%20OR%20"power%20cuts"%20OR%20"power%20cut"%20OR%20"power%20went%20out"%20OR%20"power%20interuption"%20OR%20"brownout"%20OR%20"power%20goes%20out"%20OR%20"brownouts"%20OR%20"without%20power"%20near%3A"Arizona"%20within%3A15mi%20-filter%3Aretweets%20since%3A2014-01-01%20until%3A2016-12-31&l=en
# INFO: Using proxy 159.138.3.119:80
# INFO: Retrying... (Attempts left: 34)
# INFO: Scraping tweets from https://twitter.com/search?f=tweets&vertical=default&q="power%20outage"%20OR%20"power%20is%20out"%20OR%20"power's%20out"%20OR%20"blackouts"%20OR%20"blackout"%20-"video%20game"%20OR%20"power%20failure"%20OR%20"power%20failures"%20OR%20"no%20electricity"%20OR%20"power%20shortage"%20OR%20"electrical%20failure"%20OR%20"power%20loss"%20OR%20"power%20cuts"%20OR%20"power%20cut"%20OR%20"power%20went%20out"%20OR%20"power%20interuption"%20OR%20"brownout"%20OR%20"power%20goes%20out"%20OR%20"brownouts"%20OR%20"without%20power"%20near%3A"Arizona"%20within%3A15mi%20-filter%3Aretweets%20since%3A2014-01-01%20until%3A2016-12-31&l=en
# INFO: Using proxy 103.88.234.58:32413
# INFO: Retrying... (Attempts left: 33)
# INFO: Scraping tweets from https://twitter.com/search?f=tweets&vertical=default&q="power%20outage"%20OR%20"power%20is%20out"%20OR%20"power's%20out"%20OR%20"blackouts"%20OR%20"blackout"%20-"video%20game"%20OR%20"power%20failure"%20OR%20"power%20failures"%20OR%20"no%20electricity"%20OR%20"power%20shortage"%20OR%20"electrical%20failure"%20OR%20"power%20loss"%20OR%20"power%20cuts"%20OR%20"power%20cut"%20OR%20"power%20went%20out"%20OR%20"power%20interuption"%20OR%20"brownout"%20OR%20"power%20goes%20out"%20OR%20"brownouts"%20OR%20"without%20power"%20near%3A"Arizona"%20within%3A15mi%20-filter%3Aretweets%20since%3A2014-01-01%20until%3A2016-12-31&l=en
# INFO: Using proxy 177.126.88.62:53281
# INFO: Retrying... (Attempts left: 32)
# INFO: Scraping tweets from https://twitter.com/search?f=tweets&vertical=default&q="power%20outage"%20OR%20"power%20is%20out"%20OR%20"power's%20out"%20OR%20"blackouts"%20OR%20"blackout"%20-"video%20game"%20OR%20"power%20failure"%20OR%20"power%20failures"%20OR%20"no%20electricity"%20OR%20"power%20shortage"%20OR%20"electrical%20failure"%20OR%20"power%20loss"%20OR%20"power%20cuts"%20OR%20"power%20cut"%20OR%20"power%20went%20out"%20OR%20"power%20interuption"%20OR%20"brownout"%20OR%20"power%20goes%20out"%20OR%20"brownouts"%20OR%20"without%20power"%20near%3A"Arizona"%20within%3A15mi%20-filter%3Aretweets%20since%3A2014-01-01%20until%3A2016-12-31&l=en
# INFO: Using proxy 191.242.182.132:8081
# INFO: Retrying... (Attempts left: 31)
# INFO: Scraping tweets from https://twitter.com/search?f=tweets&vertical=default&q="power%20outage"%20OR%20"power%20is%20out"%20OR%20"power's%20out"%20OR%20"blackouts"%20OR%20"blackout"%20-"video%20game"%20OR%20"power%20failure"%20OR%20"power%20failures"%20OR%20"no%20electricity"%20OR%20"power%20shortage"%20OR%20"electrical%20failure"%20OR%20"power%20loss"%20OR%20"power%20cuts"%20OR%20"power%20cut"%20OR%20"power%20went%20out"%20OR%20"power%20interuption"%20OR%20"brownout"%20OR%20"power%20goes%20out"%20OR%20"brownouts"%20OR%20"without%20power"%20near%3A"Arizona"%20within%3A15mi%20-filter%3Aretweets%20since%3A2014-01-01%20until%3A2016-12-31&l=en
# INFO: Using proxy 207.154.231.212:3128
# INFO: Retrying... (Attempts left: 30)
# INFO: Scraping tweets from https://twitter.com/search?f=tweets&vertical=default&q="power%20outage"%20OR%20"power%20is%20out"%20OR%20"power's%20out"%20OR%20"blackouts"%20OR%20"blackout"%20-"video%20game"%20OR%20"power%20failure"%20OR%20"power%20failures"%20OR%20"no%20electricity"%20OR%20"power%20shortage"%20OR%20"electrical%20failure"%20OR%20"power%20loss"%20OR%20"power%20cuts"%20OR%20"power%20cut"%20OR%20"power%20went%20out"%20OR%20"power%20interuption"%20OR%20"brownout"%20OR%20"power%20goes%20out"%20OR%20"brownouts"%20OR%20"without%20power"%20near%3A"Arizona"%20within%3A15mi%20-filter%3Aretweets%20since%3A2014-01-01%20until%3A2016-12-31&l=en
# INFO: Using proxy 46.130.249.18:49798
# INFO: Retrying... (Attempts left: 29)
# INFO: Scraping tweets from https://twitter.com/search?f=tweets&vertical=default&q="power%20outage"%20OR%20"power%20is%20out"%20OR%20"power's%20out"%20OR%20"blackouts"%20OR%20"blackout"%20-"video%20game"%20OR%20"power%20failure"%20OR%20"power%20failures"%20OR%20"no%20electricity"%20OR%20"power%20shortage"%20OR%20"electrical%20failure"%20OR%20"power%20loss"%20OR%20"power%20cuts"%20OR%20"power%20cut"%20OR%20"power%20went%20out"%20OR%20"power%20interuption"%20OR%20"brownout"%20OR%20"power%20goes%20out"%20OR%20"brownouts"%20OR%20"without%20power"%20near%3A"Arizona"%20within%3A15mi%20-filter%3Aretweets%20since%3A2014-01-01%20until%3A2016-12-31&l=en
# INFO: Using proxy 88.199.82.66:32110
# INFO: Retrying... (Attempts left: 28)
# INFO: Scraping tweets from https://twitter.com/search?f=tweets&vertical=default&q="power%20outage"%20OR%20"power%20is%20out"%20OR%20"power's%20out"%20OR%20"blackouts"%20OR%20"blackout"%20-"video%20game"%20OR%20"power%20failure"%20OR%20"power%20failures"%20OR%20"no%20electricity"%20OR%20"power%20shortage"%20OR%20"electrical%20failure"%20OR%20"power%20loss"%20OR%20"power%20cuts"%20OR%20"power%20cut"%20OR%20"power%20went%20out"%20OR%20"power%20interuption"%20OR%20"brownout"%20OR%20"power%20goes%20out"%20OR%20"brownouts"%20OR%20"without%20power"%20near%3A"Arizona"%20within%3A15mi%20-filter%3Aretweets%20since%3A2014-01-01%20until%3A2016-12-31&l=en
# INFO: Using proxy 83.171.99.160:47114
# INFO: Retrying... (Attempts left: 27)
# INFO: Scraping tweets from https://twitter.com/search?f=tweets&vertical=default&q="power%20outage"%20OR%20"power%20is%20out"%20OR%20"power's%20out"%20OR%20"blackouts"%20OR%20"blackout"%20-"video%20game"%20OR%20"power%20failure"%20OR%20"power%20failures"%20OR%20"no%20electricity"%20OR%20"power%20shortage"%20OR%20"electrical%20failure"%20OR%20"power%20loss"%20OR%20"power%20cuts"%20OR%20"power%20cut"%20OR%20"power%20went%20out"%20OR%20"power%20interuption"%20OR%20"brownout"%20OR%20"power%20goes%20out"%20OR%20"brownouts"%20OR%20"without%20power"%20near%3A"Arizona"%20within%3A15mi%20-filter%3Aretweets%20since%3A2014-01-01%20until%3A2016-12-31&l=en
# INFO: Using proxy 91.192.4.27:8080
# INFO: Retrying... (Attempts left: 26)
# INFO: Scraping tweets from https://twitter.com/search?f=tweets&vertical=default&q="power%20outage"%20OR%20"power%20is%20out"%20OR%20"power's%20out"%20OR%20"blackouts"%20OR%20"blackout"%20-"video%20game"%20OR%20"power%20failure"%20OR%20"power%20failures"%20OR%20"no%20electricity"%20OR%20"power%20shortage"%20OR%20"electrical%20failure"%20OR%20"power%20loss"%20OR%20"power%20cuts"%20OR%20"power%20cut"%20OR%20"power%20went%20out"%20OR%20"power%20interuption"%20OR%20"brownout"%20OR%20"power%20goes%20out"%20OR%20"brownouts"%20OR%20"without%20power"%20near%3A"Arizona"%20within%3A15mi%20-filter%3Aretweets%20since%3A2014-01-01%20until%3A2016-12-31&l=en
# INFO: Using proxy 67.205.174.209:3128
# INFO: Retrying... (Attempts left: 25)
# INFO: Scraping tweets from https://twitter.com/search?f=tweets&vertical=default&q="power%20outage"%20OR%20"power%20is%20out"%20OR%20"power's%20out"%20OR%20"blackouts"%20OR%20"blackout"%20-"video%20game"%20OR%20"power%20failure"%20OR%20"power%20failures"%20OR%20"no%20electricity"%20OR%20"power%20shortage"%20OR%20"electrical%20failure"%20OR%20"power%20loss"%20OR%20"power%20cuts"%20OR%20"power%20cut"%20OR%20"power%20went%20out"%20OR%20"power%20interuption"%20OR%20"brownout"%20OR%20"power%20goes%20out"%20OR%20"brownouts"%20OR%20"without%20power"%20near%3A"Arizona"%20within%3A15mi%20-filter%3Aretweets%20since%3A2014-01-01%20until%3A2016-12-31&l=en
# INFO: Using proxy 1.10.189.126:57959
# INFO: Retrying... (Attempts left: 24)
# INFO: Scraping tweets from https://twitter.com/search?f=tweets&vertical=default&q="power%20outage"%20OR%20"power%20is%20out"%20OR%20"power's%20out"%20OR%20"blackouts"%20OR%20"blackout"%20-"video%20game"%20OR%20"power%20failure"%20OR%20"power%20failures"%20OR%20"no%20electricity"%20OR%20"power%20shortage"%20OR%20"electrical%20failure"%20OR%20"power%20loss"%20OR%20"power%20cuts"%20OR%20"power%20cut"%20OR%20"power%20went%20out"%20OR%20"power%20interuption"%20OR%20"brownout"%20OR%20"power%20goes%20out"%20OR%20"brownouts"%20OR%20"without%20power"%20near%3A"Arizona"%20within%3A15mi%20-filter%3Aretweets%20since%3A2014-01-01%20until%3A2016-12-31&l=en
# INFO: Using proxy 161.202.226.195:80
# INFO: Retrying... (Attempts left: 23)
# INFO: Scraping tweets from https://twitter.com/search?f=tweets&vertical=default&q="power%20outage"%20OR%20"power%20is%20out"%20OR%20"power's%20out"%20OR%20"blackouts"%20OR%20"blackout"%20-"video%20game"%20OR%20"power%20failure"%20OR%20"power%20failures"%20OR%20"no%20electricity"%20OR%20"power%20shortage"%20OR%20"electrical%20failure"%20OR%20"power%20loss"%20OR%20"power%20cuts"%20OR%20"power%20cut"%20OR%20"power%20went%20out"%20OR%20"power%20interuption"%20OR%20"brownout"%20OR%20"power%20goes%20out"%20OR%20"brownouts"%20OR%20"without%20power"%20near%3A"Arizona"%20within%3A15mi%20-filter%3Aretweets%20since%3A2014-01-01%20until%3A2016-12-31&l=en
# INFO: Using proxy 118.172.201.89:38156
# INFO: Retrying... (Attempts left: 22)
# INFO: Scraping tweets from https://twitter.com/search?f=tweets&vertical=default&q="power%20outage"%20OR%20"power%20is%20out"%20OR%20"power's%20out"%20OR%20"blackouts"%20OR%20"blackout"%20-"video%20game"%20OR%20"power%20failure"%20OR%20"power%20failures"%20OR%20"no%20electricity"%20OR%20"power%20shortage"%20OR%20"electrical%20failure"%20OR%20"power%20loss"%20OR%20"power%20cuts"%20OR%20"power%20cut"%20OR%20"power%20went%20out"%20OR%20"power%20interuption"%20OR%20"brownout"%20OR%20"power%20goes%20out"%20OR%20"brownouts"%20OR%20"without%20power"%20near%3A"Arizona"%20within%3A15mi%20-filter%3Aretweets%20since%3A2014-01-01%20until%3A2016-12-31&l=en
# INFO: Using proxy 202.158.77.122:51671
# INFO: Retrying... (Attempts left: 21)
# INFO: Scraping tweets from https://twitter.com/search?f=tweets&vertical=default&q="power%20outage"%20OR%20"power%20is%20out"%20OR%20"power's%20out"%20OR%20"blackouts"%20OR%20"blackout"%20-"video%20game"%20OR%20"power%20failure"%20OR%20"power%20failures"%20OR%20"no%20electricity"%20OR%20"power%20shortage"%20OR%20"electrical%20failure"%20OR%20"power%20loss"%20OR%20"power%20cuts"%20OR%20"power%20cut"%20OR%20"power%20went%20out"%20OR%20"power%20interuption"%20OR%20"brownout"%20OR%20"power%20goes%20out"%20OR%20"brownouts"%20OR%20"without%20power"%20near%3A"Arizona"%20within%3A15mi%20-filter%3Aretweets%20since%3A2014-01-01%20until%3A2016-12-31&l=en
# INFO: Using proxy 91.197.132.66:53281
# INFO: Retrying... (Attempts left: 20)
# INFO: Scraping tweets from https://twitter.com/search?f=tweets&vertical=default&q="power%20outage"%20OR%20"power%20is%20out"%20OR%20"power's%20out"%20OR%20"blackouts"%20OR%20"blackout"%20-"video%20game"%20OR%20"power%20failure"%20OR%20"power%20failures"%20OR%20"no%20electricity"%20OR%20"power%20shortage"%20OR%20"electrical%20failure"%20OR%20"power%20loss"%20OR%20"power%20cuts"%20OR%20"power%20cut"%20OR%20"power%20went%20out"%20OR%20"power%20interuption"%20OR%20"brownout"%20OR%20"power%20goes%20out"%20OR%20"brownouts"%20OR%20"without%20power"%20near%3A"Arizona"%20within%3A15mi%20-filter%3Aretweets%20since%3A2014-01-01%20until%3A2016-12-31&l=en
# INFO: Using proxy 139.59.101.223:8080
# INFO: Retrying... (Attempts left: 19)
# ...
# INFO: Using proxy 181.113.225.198:53281
# INFO: Scraping tweets from https://twitter.com/i/search/timeline?f=tweets&vertical=default&include_available_features=1&include_entities=1&reset_error_state=false&src=typd&max_position=thGAVUV0VFVBaCgL-B3_fy1x4WgoC3oZGa8IMhEjUAFQAlAFUAFQAA&q="power%20outage"%20OR%20"power%20is%20out"%20OR%20"power's%20out"%20OR%20"blackouts"%20OR%20"blackout"%20-"video%20game"%20OR%20"power%20failure"%20OR%20"power%20failures"%20OR%20"no%20electricity"%20OR%20"power%20shortage"%20OR%20"electrical%20failure"%20OR%20"power%20loss"%20OR%20"power%20cuts"%20OR%20"power%20cut"%20OR%20"power%20went%20out"%20OR%20"power%20interuption"%20OR%20"brownout"%20OR%20"power%20goes%20out"%20OR%20"brownouts"%20OR%20"without%20power"%20near%3A"District%20of%20Columbia"%20within%3A15mi%20-filter%3Aretweets%20since%3A2016-12-31%20until%3A2019-12-31&l=en
# INFO: Using proxy 197.159.23.174:39150
# INFO: Scraping tweets from https://twitter.com/i/search/timeline?f=tweets&vertical=default&include_available_features=1&include_entities=1&reset_error_state=false&src=typd&max_position=thGAVUV0VFVBaAwMCw4r_0-QwWhsCwwb-XjM0WEjUAFQAlAFUAFQAA&q="power%20outage"%20OR%20"power%20is%20out"%20OR%20"power's%20out"%20OR%20"blackouts"%20OR%20"blackout"%20-"video%20game"%20OR%20"power%20failure"%20OR%20"power%20failures"%20OR%20"no%20electricity"%20OR%20"power%20shortage"%20OR%20"electrical%20failure"%20OR%20"power%20loss"%20OR%20"power%20cuts"%20OR%20"power%20cut"%20OR%20"power%20went%20out"%20OR%20"power%20interuption"%20OR%20"brownout"%20OR%20"power%20goes%20out"%20OR%20"brownouts"%20OR%20"without%20power"%20near%3A"District%20of%20Columbia"%20within%3A15mi%20-filter%3Aretweets%20since%3A2014-01-01%20until%3A2016-12-31&l=en
# INFO: Using proxy 62.24.109.15:57282
# INFO: Scraping tweets from https://twitter.com/i/search/timeline?f=tweets&vertical=default&include_available_features=1&include_entities=1&reset_error_state=false&src=typd&max_position=thGAVUV0VFVBaCwLaNrsbagh4WgoC3oZGa8IMhEjUAFQAlAFUAFQAA&q="power%20outage"%20OR%20"power%20is%20out"%20OR%20"power's%20out"%20OR%20"blackouts"%20OR%20"blackout"%20-"video%20game"%20OR%20"power%20failure"%20OR%20"power%20failures"%20OR%20"no%20electricity"%20OR%20"power%20shortage"%20OR%20"electrical%20failure"%20OR%20"power%20loss"%20OR%20"power%20cuts"%20OR%20"power%20cut"%20OR%20"power%20went%20out"%20OR%20"power%20interuption"%20OR%20"brownout"%20OR%20"power%20goes%20out"%20OR%20"brownouts"%20OR%20"without%20power"%20near%3A"District%20of%20Columbia"%20within%3A15mi%20-filter%3Aretweets%20since%3A2016-12-31%20until%3A2019-12-31&l=en
# INFO: Using proxy 89.216.48.230:44061
# INFO: Scraping tweets from https://twitter.com/i/search/timeline?f=tweets&vertical=default&include_available_features=1&include_entities=1&reset_error_state=false&src=typd&max_position=thGAVUV0VFVBaAwMG4gpSA5wwWhsCwwb-XjM0WEjUAFQAlAFUAFQAA&q="power%20outage"%20OR%20"power%20is%20out"%20OR%20"power's%20out"%20OR%20"blackouts"%20OR%20"blackout"%20-"video%20game"%20OR%20"power%20failure"%20OR%20"power%20failures"%20OR%20"no%20electricity"%20OR%20"power%20shortage"%20OR%20"electrical%20failure"%20OR%20"power%20loss"%20OR%20"power%20cuts"%20OR%20"power%20cut"%20OR%20"power%20went%20out"%20OR%20"power%20interuption"%20OR%20"brownout"%20OR%20"power%20goes%20out"%20OR%20"brownouts"%20OR%20"without%20power"%20near%3A"District%20of%20Columbia"%20within%3A15mi%20-filter%3Aretweets%20since%3A2014-01-01%20until%3A2016-12-31&l=en
# INFO: Using proxy 181.129.138.114:52892
# INFO: Scraping tweets from https://twitter.com/i/search/timeline?f=tweets&vertical=default&include_available_features=1&include_entities=1&reset_error_state=false&src=typd&max_position=thGAVUV0VFVBaAgL-h-ee24x0WgoC3oZGa8IMhEjUAFQAlAFUAFQAA&q="power%20outage"%20OR%20"power%20is%20out"%20OR%20"power's%20out"%20OR%20"blackouts"%20OR%20"blackout"%20-"video%20game"%20OR%20"power%20failure"%20OR%20"power%20failures"%20OR%20"no%20electricity"%20OR%20"power%20shortage"%20OR%20"electrical%20failure"%20OR%20"power%20loss"%20OR%20"power%20cuts"%20OR%20"power%20cut"%20OR%20"power%20went%20out"%20OR%20"power%20interuption"%20OR%20"brownout"%20OR%20"power%20goes%20out"%20OR%20"brownouts"%20OR%20"without%20power"%20near%3A"District%20of%20Columbia"%20within%3A15mi%20-filter%3Aretweets%20since%3A2016-12-31%20until%3A2019-12-31&l=en
# INFO: Using proxy 109.238.222.5:46238
# INFO: Scraping tweets from https://twitter.com/i/search/timeline?f=tweets&vertical=default&include_available_features=1&include_entities=1&reset_error_state=false&src=typd&max_position=thGAVUV0VFVBaAgMPQ9sa10wwWhsCwwb-XjM0WEjUAFQAlAFUAFQAA&q="power%20outage"%20OR%20"power%20is%20out"%20OR%20"power's%20out"%20OR%20"blackouts"%20OR%20"blackout"%20-"video%20game"%20OR%20"power%20failure"%20OR%20"power%20failures"%20OR%20"no%20electricity"%20OR%20"power%20shortage"%20OR%20"electrical%20failure"%20OR%20"power%20loss"%20OR%20"power%20cuts"%20OR%20"power%20cut"%20OR%20"power%20went%20out"%20OR%20"power%20interuption"%20OR%20"brownout"%20OR%20"power%20goes%20out"%20OR%20"brownouts"%20OR%20"without%20power"%20near%3A"District%20of%20Columbia"%20within%3A15mi%20-filter%3Aretweets%20since%3A2014-01-01%20until%3A2016-12-31&l=en
# INFO: Using proxy 92.46.58.110:48144
# INFO: Twitter returned : 'has_more_items'
# INFO: Got 1142 tweets for "power%20outage"%20OR%20"power%20is%20out"%20OR%20"power's%20out"%20OR%20"blackouts"%20OR%20"blackout"%20-"video%20game"%20OR%20"power%20failure"%20OR%20"power%20failures"%20OR%20"no%20electricity"%20OR%20"power%20shortage"%20OR%20"electrical%20failure"%20OR%20"power%20loss"%20OR%20"power%20cuts"%20OR%20"power%20cut"%20OR%20"power%20went%20out"%20OR%20"power%20interuption"%20OR%20"brownout"%20OR%20"power%20goes%20out"%20OR%20"brownouts"%20OR%20"without%20power"%20near%3A"District%20of%20Columbia"%20within%3A15mi%20-filter%3Aretweets%20since%3A2016-12-31%20until%3A2019-12-31.
# INFO: Got 1142 tweets (1142 new).
# INFO: Scraping tweets from https://twitter.com/i/search/timeline?f=tweets&vertical=default&include_available_features=1&include_entities=1&reset_error_state=false&src=typd&max_position=thGAVUV0VFVBaAgMPAxZbnygwWhsCwwb-XjM0WEjUAFQAlAFUAFQAA&q="power%20outage"%20OR%20"power%20is%20out"%20OR%20"power's%20out"%20OR%20"blackouts"%20OR%20"blackout"%20-"video%20game"%20OR%20"power%20failure"%20OR%20"power%20failures"%20OR%20"no%20electricity"%20OR%20"power%20shortage"%20OR%20"electrical%20failure"%20OR%20"power%20loss"%20OR%20"power%20cuts"%20OR%20"power%20cut"%20OR%20"power%20went%20out"%20OR%20"power%20interuption"%20OR%20"brownout"%20OR%20"power%20goes%20out"%20OR%20"brownouts"%20OR%20"without%20power"%20near%3A"District%20of%20Columbia"%20within%3A15mi%20-filter%3Aretweets%20since%3A2014-01-01%20until%3A2016-12-31&l=en
# INFO: Using proxy 149.28.245.254:8080
# INFO: Scraping tweets from https://twitter.com/i/search/timeline?f=tweets&vertical=default&include_available_features=1&include_entities=1&reset_error_state=false&src=typd&max_position=thGAVUV0VFVBaAgMP0u9mVtgwWhsCwwb-XjM0WEjUAFQAlAFUAFQAA&q="power%20outage"%20OR%20"power%20is%20out"%20OR%20"power's%20out"%20OR%20"blackouts"%20OR%20"blackout"%20-"video%20game"%20OR%20"power%20failure"%20OR%20"power%20failures"%20OR%20"no%20electricity"%20OR%20"power%20shortage"%20OR%20"electrical%20failure"%20OR%20"power%20loss"%20OR%20"power%20cuts"%20OR%20"power%20cut"%20OR%20"power%20went%20out"%20OR%20"power%20interuption"%20OR%20"brownout"%20OR%20"power%20goes%20out"%20OR%20"brownouts"%20OR%20"without%20power"%20near%3A"District%20of%20Columbia"%20within%3A15mi%20-filter%3Aretweets%20since%3A2014-01-01%20until%3A2016-12-31&l=en
# INFO: Using proxy 138.197.222.35:8080
# INFO: Scraping tweets from https://twitter.com/i/search/timeline?f=tweets&vertical=default&include_available_features=1&include_entities=1&reset_error_state=false&src=typd&max_position=thGAVUV0VFVBaAgMSIsvOOqQwWhsCwwb-XjM0WEjUAFQAlAFUAFQAA&q="power%20outage"%20OR%20"power%20is%20out"%20OR%20"power's%20out"%20OR%20"blackouts"%20OR%20"blackout"%20-"video%20game"%20OR%20"power%20failure"%20OR%20"power%20failures"%20OR%20"no%20electricity"%20OR%20"power%20shortage"%20OR%20"electrical%20failure"%20OR%20"power%20loss"%20OR%20"power%20cuts"%20OR%20"power%20cut"%20OR%20"power%20went%20out"%20OR%20"power%20interuption"%20OR%20"brownout"%20OR%20"power%20goes%20out"%20OR%20"brownouts"%20OR%20"without%20power"%20near%3A"District%20of%20Columbia"%20within%3A15mi%20-filter%3Aretweets%20since%3A2014-01-01%20until%3A2016-12-31&l=en
# INFO: Using proxy 45.226.48.38:60143
# INFO: Scraping tweets from https://twitter.com/i/search/timeline?f=tweets&vertical=default&include_available_features=1&include_entities=1&reset_error_state=false&src=typd&max_position=thGAVUV0VFVBaAwMDo1fGToAwWhsCwwb-XjM0WEjUAFQAlAFUAFQAA&q="power%20outage"%20OR%20"power%20is%20out"%20OR%20"power's%20out"%20OR%20"blackouts"%20OR%20"blackout"%20-"video%20game"%20OR%20"power%20failure"%20OR%20"power%20failures"%20OR%20"no%20electricity"%20OR%20"power%20shortage"%20OR%20"electrical%20failure"%20OR%20"power%20loss"%20OR%20"power%20cuts"%20OR%20"power%20cut"%20OR%20"power%20went%20out"%20OR%20"power%20interuption"%20OR%20"brownout"%20OR%20"power%20goes%20out"%20OR%20"brownouts"%20OR%20"without%20power"%20near%3A"District%20of%20Columbia"%20within%3A15mi%20-filter%3Aretweets%20since%3A2014-01-01%20until%3A2016-12-31&l=en
# INFO: Using proxy 178.213.130.159:60253
# INFO: Scraping tweets from https://twitter.com/i/search/timeline?f=tweets&vertical=default&include_available_features=1&include_entities=1&reset_error_state=false&src=typd&max_position=thGAVUV0VFVBaAgMGAsL7oiAwWhsCwwb-XjM0WEjUAFQAlAFUAFQAA&q="power%20outage"%20OR%20"power%20is%20out"%20OR%20"power's%20out"%20OR%20"blackouts"%20OR%20"blackout"%20-"video%20game"%20OR%20"power%20failure"%20OR%20"power%20failures"%20OR%20"no%20electricity"%20OR%20"power%20shortage"%20OR%20"electrical%20failure"%20OR%20"power%20loss"%20OR%20"power%20cuts"%20OR%20"power%20cut"%20OR%20"power%20went%20out"%20OR%20"power%20interuption"%20OR%20"brownout"%20OR%20"power%20goes%20out"%20OR%20"brownouts"%20OR%20"without%20power"%20near%3A"District%20of%20Columbia"%20within%3A15mi%20-filter%3Aretweets%20since%3A2014-01-01%20until%3A2016-12-31&l=en
# INFO: Using proxy 181.129.140.226:38681
# INFO: Scraping tweets from https://twitter.com/i/search/timeline?f=tweets&vertical=default&include_available_features=1&include_entities=1&reset_error_state=false&src=typd&max_position=thGAVUV0VFVBaAwMC4i_jN_wsWhsCwwb-XjM0WEjUAFQAlAFUAFQAA&q="power%20outage"%20OR%20"power%20is%20out"%20OR%20"power's%20out"%20OR%20"blackouts"%20OR%20"blackout"%20-"video%20game"%20OR%20"power%20failure"%20OR%20"power%20failures"%20OR%20"no%20electricity"%20OR%20"power%20shortage"%20OR%20"electrical%20failure"%20OR%20"power%20loss"%20OR%20"power%20cuts"%20OR%20"power%20cut"%20OR%20"power%20went%20out"%20OR%20"power%20interuption"%20OR%20"brownout"%20OR%20"power%20goes%20out"%20OR%20"brownouts"%20OR%20"without%20power"%20near%3A"District%20of%20Columbia"%20within%3A15mi%20-filter%3Aretweets%20since%3A2014-01-01%20until%3A2016-12-31&l=en
# INFO: Using proxy 197.159.23.174:39150
# INFO: Scraping tweets from https://twitter.com/i/search/timeline?f=tweets&vertical=default&include_available_features=1&include_entities=1&reset_error_state=false&src=typd&max_position=thGAVUV0VFVBaAwMOArr7Y9wsWhsCwwb-XjM0WEjUAFQAlAFUAFQAA&q="power%20outage"%20OR%20"power%20is%20out"%20OR%20"power's%20out"%20OR%20"blackouts"%20OR%20"blackout"%20-"video%20game"%20OR%20"power%20failure"%20OR%20"power%20failures"%20OR%20"no%20electricity"%20OR%20"power%20shortage"%20OR%20"electrical%20failure"%20OR%20"power%20loss"%20OR%20"power%20cuts"%20OR%20"power%20cut"%20OR%20"power%20went%20out"%20OR%20"power%20interuption"%20OR%20"brownout"%20OR%20"power%20goes%20out"%20OR%20"brownouts"%20OR%20"without%20power"%20near%3A"District%20of%20Columbia"%20within%3A15mi%20-filter%3Aretweets%20since%3A2014-01-01%20until%3A2016-12-31&l=en
# INFO: Using proxy 89.216.48.230:44061
# INFO: Scraping tweets from https://twitter.com/i/search/timeline?f=tweets&vertical=default&include_available_features=1&include_entities=1&reset_error_state=false&src=typd&max_position=thGAVUV0VFVBaAgMCI-sCd3wsWhsCwwb-XjM0WEjUAFQAlAFUAFQAA&q="power%20outage"%20OR%20"power%20is%20out"%20OR%20"power's%20out"%20OR%20"blackouts"%20OR%20"blackout"%20-"video%20game"%20OR%20"power%20failure"%20OR%20"power%20failures"%20OR%20"no%20electricity"%20OR%20"power%20shortage"%20OR%20"electrical%20failure"%20OR%20"power%20loss"%20OR%20"power%20cuts"%20OR%20"power%20cut"%20OR%20"power%20went%20out"%20OR%20"power%20interuption"%20OR%20"brownout"%20OR%20"power%20goes%20out"%20OR%20"brownouts"%20OR%20"without%20power"%20near%3A"District%20of%20Columbia"%20within%3A15mi%20-filter%3Aretweets%20since%3A2014-01-01%20until%3A2016-12-31&l=en
# INFO: Using proxy 109.238.222.5:46238
# INFO: Scraping tweets from https://twitter.com/i/search/timeline?f=tweets&vertical=default&include_available_features=1&include_entities=1&reset_error_state=false&src=typd&max_position=thGAVUV0VFVBaAwMOwobzq0AsWhsCwwb-XjM0WEjUAFQAlAFUAFQAA&q="power%20outage"%20OR%20"power%20is%20out"%20OR%20"power's%20out"%20OR%20"blackouts"%20OR%20"blackout"%20-"video%20game"%20OR%20"power%20failure"%20OR%20"power%20failures"%20OR%20"no%20electricity"%20OR%20"power%20shortage"%20OR%20"electrical%20failure"%20OR%20"power%20loss"%20OR%20"power%20cuts"%20OR%20"power%20cut"%20OR%20"power%20went%20out"%20OR%20"power%20interuption"%20OR%20"brownout"%20OR%20"power%20goes%20out"%20OR%20"brownouts"%20OR%20"without%20power"%20near%3A"District%20of%20Columbia"%20within%3A15mi%20-filter%3Aretweets%20since%3A2014-01-01%20until%3A2016-12-31&l=en
# INFO: Using proxy 187.120.253.119:30181
# INFO: Scraping tweets from https://twitter.com/i/search/timeline?f=tweets&vertical=default&include_available_features=1&include_entities=1&reset_error_state=false&src=typd&max_position=thGAVUV0VFVBaAgMPkn7DszQsWhsCwwb-XjM0WEjUAFQAlAFUAFQAA&q="power%20outage"%20OR%20"power%20is%20out"%20OR%20"power's%20out"%20OR%20"blackouts"%20OR%20"blackout"%20-"video%20game"%20OR%20"power%20failure"%20OR%20"power%20failures"%20OR%20"no%20electricity"%20OR%20"power%20shortage"%20OR%20"electrical%20failure"%20OR%20"power%20loss"%20OR%20"power%20cuts"%20OR%20"power%20cut"%20OR%20"power%20went%20out"%20OR%20"power%20interuption"%20OR%20"brownout"%20OR%20"power%20goes%20out"%20OR%20"brownouts"%20OR%20"without%20power"%20near%3A"District%20of%20Columbia"%20within%3A15mi%20-filter%3Aretweets%20since%3A2014-01-01%20until%3A2016-12-31&l=en
# INFO: Using proxy 78.8.126.198:8080
# INFO: Twitter returned : 'has_more_items'
# INFO: Got 1184 tweets for "power%20outage"%20OR%20"power%20is%20out"%20OR%20"power's%20out"%20OR%20"blackouts"%20OR%20"blackout"%20-"video%20game"%20OR%20"power%20failure"%20OR%20"power%20failures"%20OR%20"no%20electricity"%20OR%20"power%20shortage"%20OR%20"electrical%20failure"%20OR%20"power%20loss"%20OR%20"power%20cuts"%20OR%20"power%20cut"%20OR%20"power%20went%20out"%20OR%20"power%20interuption"%20OR%20"brownout"%20OR%20"power%20goes%20out"%20OR%20"brownouts"%20OR%20"without%20power"%20near%3A"District%20of%20Columbia"%20within%3A15mi%20-filter%3Aretweets%20since%3A2014-01-01%20until%3A2016-12-31.
# INFO: Got 2326 tweets (1184 new).
# 59.15186378161113

# %%
df.head()
# Out:
#                                                tweet location       user_name  \
# 0  And we could spend the rest of the money on ra...  Alabama        samd9273
# 1  We sorry to hear the power is out. Please DM t...  Alabama    alabamapower
# 2  @DrX1304 think of how many ducks we could buy ...  Alabama        samd9273
# 3                                 It’s spooky season  Alabama  OMGItsBlackout
# 4  Newsom Raked In Big Money From Public Utility ...  Alabama      deenie7940
#
#            time_stamp  num_retweets  num_likes
# 0 2019-10-31 22:11:35             0          0
# 1 2019-10-31 21:53:10             0          0
# 2 2019-10-31 21:44:15             0          1
# 3 2019-10-31 18:17:20             0          0
# 4 2019-10-31 13:58:11             0          0

# %%
df.shape
# Out:
# (19948, 6)

# %%
df.describe()
# Out:
#        num_retweets     num_likes
# count  19948.000000  19948.000000
# mean       2.465661      8.275566
# std       63.400604    243.603913
# min        0.000000      0.000000
# 25%        0.000000      0.000000
# 50%        0.000000      0.000000
# 75%        0.000000      2.000000
# max     5988.000000  23759.000000

# %%
df['location'].value_counts()
# Out:
# New York                7553
# District of Columbia    2326
# Washington              2273
# California              1666
# Massachusetts           1275
# Georgia                  472
# South Carolina           466
# Michigan                 417
# Texas                    361
# Oklahoma                 288
# Wyoming                  270
# Oregon                   257
# Maryland                 177
# Tennessee                164
# Rhode Island             160
# Pennsylvania             142
# Connecticut              131
# Ohio                     123
# Maine                    114
# Missouri                 102
# Minnesota                 92
# Florida                   85
# Delaware                  81
# Louisiana                 78
# Kentucky                  76
# Utah                      71
# Kansas                    66
# Alabama                   62
# New Jersey                54
# Alaska                    54
# Arkansas                  53
# Colorado                  53
# Virginia                  51
# Nevada                    48
# Arizona                   45
# Iowa                      43
# Mississippi               35
# Nebraska                  30
# Idaho                     28
# Vermont                   28
# Hawaii                    22
# Indiana                   16
# Montana                   12
# New Hampshire             10
# New Mexico                 6
# South Dakota               6
# Wisconsin                  4
# West Virginia              2
# Name: location, dtype: int64

# %%
print([tweet for tweet in df['tweet'][:5]])
# Out:
# ['And we could spend the rest of the money on rabbits that we can tend to living off the fatta of the land', 'We sorry to hear the power is out. Please DM the full service address, so we can get the issue reported. -Dorie j', '@DrX1304 think of how many ducks we could buy with this moneyhttps://twitter.com/pulte/status/1189680670827778048\xa0…', 'It’s spooky season', 'Newsom Raked In Big Money From Public Utility He Is Now Chiding For Fires And Rolling Blackouts https://townhall.com/tipsheet/bethbaumann/2019/10/30/newsom-raked-in-big-money-from-public-utility-he-is-now-chiding-for-fires-and-rol-n2555643\xa0…']

# %%
# add a word count column
df['tweet_word_count'] = df['tweet'].apply(lambda post: len(post.split()))

# %%
df.head()
# Out:
#                                                tweet location       user_name  \
# 0  And we could spend the rest of the money on ra...  Alabama        samd9273
# 1  We sorry to hear the power is out. Please DM t...  Alabama    alabamapower
# 2  @DrX1304 think of how many ducks we could buy ...  Alabama        samd9273
# 3                                 It’s spooky season  Alabama  OMGItsBlackout
# 4  Newsom Raked In Big Money From Public Utility ...  Alabama      deenie7940
#
#            time_stamp  num_retweets  num_likes  tweet_word_count
# 0 2019-10-31 22:11:35             0          0                23
# 1 2019-10-31 21:53:10             0          0                23
# 2 2019-10-31 21:44:15             0          1                13
# 3 2019-10-31 18:17:20             0          0                 3
# 4 2019-10-31 13:58:11             0          0                19

# %%
# save the dataframe file
df.to_csv('../Data/twitter_states_2014_19.csv', index=False)

# %%
df['time_stamp'].sort_values()
# Out:
# 13480   2014-01-01 00:32:02
# 8484    2014-01-01 01:06:37
# 4596    2014-01-01 01:26:18
# 14391   2014-01-01 01:49:04
# 4595    2014-01-01 01:52:30
#                 ...
# 13926   2019-10-31 22:56:24
# 17622   2019-10-31 23:02:50
# 17642   2019-10-31 23:02:50
# 15093   2019-10-31 23:02:50
# 15073   2019-10-31 23:02:50
# Name: time_stamp, Length: 19948, dtype: datetime64[ns]
